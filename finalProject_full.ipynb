# %% [markdown]
# # Propaganda Detector Training

# %% [markdown]
# ## 1. Environment Set Up

# %%
# %pwd
# Out:
# '/content'

# %%
# %ls
# Out:
# sample_data/

# %%
# !rm -rf propaganda-detector
# !git clone https://github.com/Minal-Arunashalam/propaganda-detector.git
# Out:
# Cloning into 'propaganda-detector'...
# remote: Enumerating objects: 1319, done.
# remote: Counting objects: 100% (1319/1319), done.
# remote: Compressing objects: 100% (1201/1201), done.
# remote: Total 1319 (delta 88), reused 1279 (delta 51), pack-reused 0 (from 0)
# Receiving objects: 100% (1319/1319), 2.15 MiB | 27.87 MiB/s, done.
# Resolving deltas: 100% (88/88), done.

# %%
# %cd /content/propaganda-detector
# !pip install -r requirements.txt
# Out:
# /content/propaganda-detector
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 39.7 MB/s eta 0:00:00
# ...

# %%
import torch
print("pytorch version:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
# Out:
# pytorch version: 2.9.0+cu126
# cuda available: True

# %% [markdown]
# # Baselines: RoBERTa and DeBERTa

# %% [markdown]
# ## Training RoBERTa

# %%
# !python training/train.py roberta
# Out:
# Using device: cuda
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 133kB/s]
# config.json: 100% 481/481 [00:00<00:00, 2.69MB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 76.4MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 2.12MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 1.61MB/s]
# [RoBERTa] pos_weight stats - min: 7.54, max: 10.00, mean: 9.82
# 2025-12-09 22:49:46.734298: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-09 22:49:46.753544: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %% [markdown]
# ## Evaluating RoBERTa

# %%
# !python training/eval.py roberta 2
# Out:
# ...
# Evaluating RoBERTa Model
# ...
# Loading RoBERTa checkpoint from: checkpoints/roberta-base_checkpoint_epoch2.pt
# 2025-12-09 23:02:44.766257: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-09 23:02:44.783721: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765321364.802911    6626 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %% [markdown]
# ## Training DeBERTa

# %%
# !python training/train.py deberta
# Out:
# Using device: cuda
# tokenizer_config.json: 100% 52.0/52.0 [00:00<00:00, 275kB/s]
# config.json: 100% 579/579 [00:00<00:00, 4.61MB/s]
# spm.model: 100% 2.46M/2.46M [00:01<00:00, 2.07MB/s]
# /usr/local/lib/python3.12/dist-packages/transformers/convert_slow_tokenizer.py:566: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# [DeBERTa] pos_weight stats - min: 7.54, max: 10.00, mean: 9.82
# ...

# %% [markdown]
# ## Evaluating DeBERTa

# %%
# !python training/eval.py deberta 2
# Out:
# ...
# Evaluating DeBERTa Model
# ...
# Loading DeBERTa checkpoint from: checkpoints/microsoft_deberta-v3-base_checkpoint_epoch2.pt
# /usr/local/lib/python3.12/dist-packages/transformers/convert_slow_tokenizer.py:566: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# 2025-12-09 23:23:07.414926: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %% [markdown]
# # Working with LLaMA

# %% [markdown]
# ## Huggingface Authentication

# %%
from huggingface_hub import login
login()

# %% [markdown]
# ## Training LLaMA

# %%
# !python training/train.py llama
# Out:
# 2025-12-09 23:26:09.513564: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-09 23:26:09.531445: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765322769.553133   12746 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765322769.559764   12746 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## Evaluating LLaMA

# %%
# !python training/eval.py llama 1
# Out:
# ...
# Evaluating Llama Model (LoRA=True)
# ...
# 2025-12-10 00:48:38.793736: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-10 00:48:38.812763: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765327718.834256   33238 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765327718.840860   33238 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # Inferencing

# %%
# !python training/inference.py llama 27 2 0.3
# Out:
# Loading llama model (epoch 2)...
# 2025-12-10 00:51:02.332763: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-10 00:51:02.351310: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765327862.373156   33872 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765327862.379791   33872 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python training/inference.py deberta 27 2 0.8
# Out:
# Loading deberta model (epoch 2)...
# /usr/local/lib/python3.12/dist-packages/transformers/convert_slow_tokenizer.py:566: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# 2025-12-10 00:51:36.917261: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...
